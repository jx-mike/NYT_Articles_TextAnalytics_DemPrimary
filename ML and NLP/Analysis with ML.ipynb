# %% [markdown]
# # ML Final Project
# **Rebecca Driever, Michael Chen, Rayna Ji**

# %%
import pandas as pd
import re
from datetime import datetime
import string
import random
import numpy as np
import time
from scipy.stats import entropy
import seaborn as sns
sns.set_style("darkgrid")

import pymongo
from pymongo import MongoClient
import json
from bson.code import Code
from bs4 import BeautifulSoup as bs 

# NLP
import nltk
from nltk import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
import gensim
from gensim.models import LdaModel
from gensim import models, corpora, similarities
# distances
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
# PCA and plot
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import matplotlib.pyplot as pPlot
from wordcloud import WordCloud, STOPWORDS
# import dependencies

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score, cross_val_predict

# %% [markdown]
# ## Inspect data in MongoDB

# %%
client = MongoClient('localhost', 27017) # connect to MongoDB
db = client['fec'] # connect to the database
db.list_collection_names()
# Out:
# ['artical_metadata', 'artical_main_content', 'delegates', 'fec Filings']

# %%
# connect to artical_main_content collection
coll_main = db['artical_main_content']

main = pd.DataFrame(list(coll_main.find()))
main.head()
# Out:
#                         _id article_index  \
# 0  5e6d9dcde410a40d1c62ff02            10
# 1  5e6d9dcde410a40d1c62ff03            11
# 2  5e6d9dcde410a40d1c62ff04            12
# 3  5e6d9dcde410a40d1c62ff05            13
# 4  5e6d9dcde410a40d1c62ff06            22
#
#                                         main_content
# 0  Before the first votes are cast in the Democra...
# 1  DES MOINES — Once upon a time, the winner of t...
# 2  SIOUX CITY, Iowa — After a long campaign of id...
# 3  CENTERVILLE, Iowa — Jill Biden was torn. Three...
# 4  DES MOINES — For a full year, Democrats owned ...

# %%
# connect to artical_metadata collection
coll_metadata = db['artical_metadata']

metadata = pd.DataFrame(list(coll_metadata.find()))
metadata.head()
# Out:
#                         _id  \
# 0  5e6da02ab0e10f7cb59126af
# 1  5e6da02ab0e10f7cb59126b0
# 2  5e6da02ab0e10f7cb59126b1
# 3  5e6da02ab0e10f7cb59126b2
# 4  5e6da02ab0e10f7cb59126b3
#
#                                             abstract  article_index  \
# 0  The Vermont senator has made exaggerated claim...             10
# 1  As if the caucusing wasn’t confusing enough, o...             11
# 2  With the Iowa caucuses set to kick off the pri...             12
# 3  She is a forceful surrogate for Joe Biden’s ca...             13
# 4  Iowa voted strongly for Barack Obama twice and...             22
#
#                                               byline document_type  \
# 0  {'original': 'By Linda Qiu', 'person': [{'firs...       article
# 1  {'original': 'By Maggie Astor and Matt Stevens...       article
# 2  {'original': 'By Jonathan Martin and Alexander...       article
# 3  {'original': 'By Katie Glueck and Steve Eder',...       article
# 4  {'original': 'By Trip Gabriel and Jeremy W. Pe...       article
#
#                                             headline  \
# 0  {'main': 'Fact-Checking Bernie Sanders Before ...
# 1  {'main': 'How Will the Winner of the Iowa Cauc...
# 2  {'main': 'Democratic Candidates Focus on All-C...
# 3  {'main': 'Why Jill Biden Is Taking Time Off to...
# 4  {'main': 'Can Democrats Beat Trump in Iowa in ...
#
#                                             keywords   news_desk print_page  \
# 0  [{'name': 'persons', 'value': 'Sanders, Bernar...  Washington         18
# 1  [{'name': 'subject', 'value': 'Presidential El...    Politics         17
# 2  [{'name': 'organizations', 'value': 'Democrati...    Politics          1
# 3  [{'name': 'persons', 'value': 'Biden, Joseph R...    Politics         16
# 4  [{'name': 'subject', 'value': 'Presidential El...    Politics         18
#
#   print_section                  pub_date section_name  slideshow_credits  \
# 0             A  2020-02-01T16:00:55+0000         U.S.                NaN
# 1             A  2020-02-01T10:00:21+0000         U.S.                NaN
# 2             A  2020-02-01T17:00:09+0000         U.S.                NaN
# 3             A  2020-02-01T10:00:21+0000         U.S.                NaN
# 4             A  2020-02-02T17:30:08+0000         U.S.                NaN
#
#                                              snippet              source  \
# 0  The Vermont senator has made exaggerated claim...  The New York Times
# 1  As if the caucusing wasn’t confusing enough, o...  The New York Times
# 2  With the Iowa caucuses set to kick off the pri...  The New York Times
# 3  She is a forceful surrogate for Joe Biden’s ca...  The New York Times
# 4  Iowa voted strongly for Barack Obama twice and...  The New York Times
#
#   subsection_name type_of_material  \
# 0        Politics             News
# 1        Politics             News
# 2        Politics             News
# 3        Politics             News
# 4        Politics             News
#
#                                                  uri  \
# 0  nyt://article/3cc0d96d-5174-57f1-b6bc-723368db...
# 1  nyt://article/ed9f6baf-a5b5-5bd1-a24e-d24e79e3...
# 2  nyt://article/98ef5f2a-10d6-5a01-bd35-f675b58e...
# 3  nyt://article/64ec07df-12ed-512e-8611-2ebed78d...
# 4  nyt://article/aad55278-31e9-5ba0-8b6c-cca34be7...
#
#                                              web_url  word_count
# 0  https://www.nytimes.com/2020/02/01/us/politics...        1849
# 1  https://www.nytimes.com/2020/02/01/us/politics...        1112
# 2  https://www.nytimes.com/2020/02/01/us/politics...        1782
# 3  https://www.nytimes.com/2020/02/01/us/politics...        2065
# 4  https://www.nytimes.com/2020/02/02/us/politics...        1703

# %%
# connect to delegates collection
coll_del = db['delegates']

delegates = pd.DataFrame(list(coll_del.find()))
delegates.head()
# Out:
#                         _id  biden_delegates  biden_win  sanders_delegates  \
# 0  5e6db6ebb0e10f7cb59129f6                6          0                 12
# 1  5e6db6ebb0e10f7cb59129f7                0          0                  9
# 2  5e6db6ebb0e10f7cb59129f8                9          0                 24
# 3  5e6db6ebb0e10f7cb59129f9               39          1                 15
# 4  5e6db6ebb0e10f7cb59129fa               44          1                  8
#
#    sanders_win           state
# 0            0            Iowa
# 1            1   New Hampshire
# 2            1          Nevada
# 3            0  South Carolina
# 4            0         Alabama

# %%
# connect to fec Filings collection
coll_fec = db['fec Filings']

fec = pd.DataFrame(list(coll_fec.find()))
fec
# Out:
#                               _id    cand_id             cand_nm  \
# 0        5e6e86ebb0e10f7cb5912a10  P60007168    Sanders, Bernard
# 1        5e6e86ebb0e10f7cb5912a11  P60007168    Sanders, Bernard
# 2        5e6e86ebb0e10f7cb5912a12  P60007168    Sanders, Bernard
# 3        5e6e86ebb0e10f7cb5912a13  P60007168    Sanders, Bernard
# 4        5e6e86ebb0e10f7cb5912a14  P60007168    Sanders, Bernard
# 13                 UNITED STATES         LEWIS, ANTHONY
# 14                  NOT EMPLOYED            SUNDT, DICK
# 15              FAST ENTERPRISES         SMITH, BRANDON
# 16              FAST ENTERPRISES         SMITH, BRANDON
# 17                       US ARMY         RAPACH, THOMAS
# 18                       US ARMY         RAPACH, THOMAS
# 19                       US ARMY         RAPACH, THOMAS
# 20       UNITED STATES AIR FORCE          MOEHLER, CODY
# 21                       US NAVY        MATHEWS, SANDER
# 22                       US ARMY       VALERY, PFIFFNER
# 23                       US NAVY        MATHEWS, SANDER
# 24         INFORMATION REQUESTED      JITVIMOL, DADALIN
# 25         INFORMATION REQUESTED      JITVIMOL, DADALIN
# 26         INFORMATION REQUESTED      JITVIMOL, DADALIN
# 27                  NOT EMPLOYED     LEDGERWOOD, JUSTIN
# 28                          USAF       EMMERLING, LOGAN
# 29                          USAF       EMMERLING, LOGAN
# ...                          ...                    ...
# 1636143                      NaN           CLARK, PETER
# 1636144                      NaN           CLARK, PETER
# 1636145                      NaN           CLARK, PETER
# 1636146                      NaN           CLARK, PETER
# 1636147                      NaN           CLARK, PETER
# 1636148                      NaN        ENSERRO, ROBERT
# 1636149                      NaN         ERIKSEN, HVARD
# 1636150                      NaN         ERIKSEN, HVARD
# 1636151                     UNGE         ERIKSEN, HVARD
# 1636152             NOT EMPLOYED          GILBERT, SARI
# 1636153                   APC AG            ANAND, RAVI
# 1636154             NOT EMPLOYED           ESTES, GLENN
# 1636155             NOT EMPLOYED           ESTES, GLENN
# 1636156             NOT EMPLOYED           ESTES, GLENN
# 1636157             NOT EMPLOYED           ESTES, GLENN
# 1636158            SELF-EMPLOYED           FREY, NADINE
# 1636159            SELF-EMPLOYED           FREY, NADINE
# 1636160                   AMCHAM          DAHLEN, PETER
# 1636161             NOT EMPLOYED       LEPAK, ALEXANDER
# 1636162             NOT EMPLOYED       LEPAK, ALEXANDER
# 1636163             NOT EMPLOYED       LEPAK, ALEXANDER
# 1636164             NOT EMPLOYED           MEEHAN, JOHN
# 1636165                      WIK  MARCUS, J SCOTT SCOTT
# 1636166                      WIK  MARCUS, J SCOTT SCOTT
# 1636167                      WIK  MARCUS, J SCOTT SCOTT
# 1636168             NOT EMPLOYED           HYNES, DAVID
# 1636169           PRAGUE COMPANY     KHODCHENKOV, PAVEL
# 1636170           PRAGUE COMPANY     KHODCHENKOV, PAVEL
# 1636171           PRAGUE COMPANY     KHODCHENKOV, PAVEL
# 1636172           PRAGUE COMPANY     KHODCHENKOV, PAVEL
#
#                        contbr_occupation contbr_st   contbr_zip election_tp  \
# 0                               MILITARY        AA  340110068.0       P2020
# 1                               MILITARY        AA  340110068.0       P2020
# 2                               MILITARY        AA  340110068.0       P2020
# 3                               MILITARY        AA  340110068.0       P2020
# 4                               MILITARY        AA  340110068.0       P2020
# 5                               MILITARY        AA  340110068.0       P2020
# 6                               MILITARY        AA  340110068.0       P2020
# 7                               MILITARY        AA  340110068.0       P2020
# 8                               MILITARY        AA  340110068.0       P2020
SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 28        1354564   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 29        1354564   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# ...           ...     ...     ...                                  ...
# 1636143   1379721   SB28A     NaN                                  NaN
# 1636144   1379721   SB28A     NaN                                  NaN
# 1636145   1379721   SB28A     NaN                                  NaN
# 1636146   1379721   SB28A     NaN                                  NaN
# 1636147   1379721   SB28A     NaN                                  NaN
# 1636148   1379721   SB28A     NaN                                  NaN
# 1636149   1379721   SB28A     NaN                                  NaN
# 1636150   1379721   SB28A     NaN                                  NaN
# 1636151   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636152   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636153   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636154   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636155   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636156   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636157   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636158   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636159   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636160   1385184   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636161   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636162   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636163   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636164   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636165   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636166   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636167   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636168   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636169   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636170   1379721   SA17A     NaN  * EARMARKED CONTRIBUTION: SEE BELOW
# 1636171   1379721   SA17A       X                                  NaN
# 1636172   1379721   SA17A       X                                  NaN
#
#         receipt_desc    tran_id
# 0                NaN   16262901
# 1                NaN   16282750
# 2                NaN   16321511
# 3                NaN   16328758
# 4                NaN   16336803
# 5                NaN   16350642
# 6                NaN   16404128
# 7                NaN   16407779
# 8                NaN   16473894
# 9                NaN   16475196
# 10               NaN   16514146
# 11               NaN   16576640
# 12               NaN   16603299
# 13               NaN   16605429
# 14               NaN   10681968
# 15               NaN   10289917
# 16               NaN   10285438
# 17               NaN   11642102
# 18               NaN   11790088
# 19               NaN   11854009
# 20               NaN   11063261
# 21               NaN   10812088
# 22               NaN   10613572
# 23               NaN   11164330
# 24               NaN   10855053
# 25               NaN   11435452
# 26               NaN   11501044
# 27               NaN   11765510
# 28               NaN   11287588
# 29               NaN   11352860
# ...              ...        ...
# 1636143       Refund  500014788
# 1636144       Refund  500014792
# 1636145       Refund  500014793
# 1636146       Refund  500014826
# 1636147       Refund  500014883
# 1636148       Refund  500015007
# 1636149       Refund  500014791
# 1636150       Refund  500014881
# 1636151          NaN    1994640
# 1636152          NaN    2081760
# 1636153          NaN    2169027
# 1636154          NaN    2021098
# 1636155          NaN    2063934
# 1636156          NaN    2105063
# 1636157          NaN    2148208
# 1636158          NaN    2162150
# 1636159          NaN    2169481
# 1636160          NaN    2136530
# 1636161          NaN    1405917
# 1636162          NaN    1442200
# 1636163          NaN    1681604
# 1636164          NaN    1358498
# 1636165          NaN    1290741
# 1636166          NaN    1636088
# 1636167          NaN    1872185
# 1636168          NaN    1781825
# 1636169          NaN    1468000
# 1636170          NaN    1619432
# 1636171          NaN    1995527
# 1636172          NaN    1995710
#
# [1636173 rows x 18 columns]

# %% [markdown]
# ## Regression on delegates won

# %%
st_del = delegates["state"].value_counts()
len(st_del)
# Out:
# 26

# %%
st = fec["contbr_st"].value_counts()
len(st)
# Out:
# 60

# %%
# create the state abbreation dictionary dataframe
states_dict = {"AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas","CA":"California","CO":"Colorado","CT":"Connecticut","DE":"Delaware","FL":"Florida","GA":"Georgia","HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana","IA":"Iowa","KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland","MA":"Massachusetts","MI":"Michigan","MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada","NH":"New Hampshire","NJ":"New Jersey","NM":"New Mexico","NY":"New York","NC":"North Carolina","ND":"North Dakota","OH":"Ohio","OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina","SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah","VT":"Vermont","VA":"Virginia","WA":"Washington","WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"}
state_items = states_dict.items()
state_list = list(state_items)

state_df = pd.DataFrame(state_list,columns=['st_abb','state'])

# %%
# merge 
delegates_st = pd.merge(delegates,state_df,on="state")

# get the unique 26 states occuring in the delegates df.
states_26 = list(delegates_st["st_abb"].unique())

# filter out the funding file based on these 26 states
fec_26 = fec[fec.contbr_st.isin(states_26)]

# %%
# get the state sum contribution amount
fec_biden_gb = fec_biden[['contbr_st', 'contb_receipt_amt']].groupby('contbr_st', as_index=False).sum()
fec_sanders_gb = fec_sanders[['contbr_st', 'contb_receipt_amt']].groupby('contbr_st', as_index=False).sum()

# %%
# a = fec_biden.groupby('contbr_nm')['contbr_st'].unique()
# fec_biden_gb_nm = pd.DataFrame.from_records(a.values.tolist()).stack().value_counts() # a series
# fec_biden_gb_nm.to_frame()

# %%
# get the state unique contributor numbers
fec_biden_gb_nm = fec_biden.groupby('contbr_st')['contbr_nm'].nunique()
fec_sanders_gb_nm = fec_sanders.groupby('contbr_st')['contbr_nm'].nunique()

fec_biden_gb_nm = fec_biden_gb_nm.reset_index()
fec_sanders_gb_nm = fec_sanders_gb_nm.reset_index()

# %%
# get the independent features ready
x_biden = pd.merge(fec_biden_gb_nm,fec_biden_gb,on='contbr_st')
x_sanders = pd.merge(fec_sanders_gb_nm,fec_sanders_gb,on='contbr_st')

# %%
x_biden
# Out:
#    contbr_st  contbr_nm  contb_receipt_amt
# 0         AL        356          201308.37
# 1         AR        159           72624.75
# 2         CA       9219         7654039.55
# 3         CO       1068          701015.58
# 4         IA        397          181933.93
# 5         ID        258          190933.50
# 6         ME        199           70132.80
# 7         MI       1048          475071.01
# 8         MN        488          204336.67
# 9         MO        532          385733.77
# 10        MS        107           50771.00
# 11        NC       1287          753100.46
# 12        ND         18            5052.33
# 13        NH        373          218623.72
# 14        NV        694          794405.86
# 15        OK        225           78634.84
# 16        SC        674          521078.64
# 17        TN        746          534043.55
# 18        TX       2751         2295828.19
# 19        UT        294          180574.66
# 20        VA       2189         1537964.52
# 21        VT        161          122177.81
# 22        WA       1623         1180548.53

# %%
x_sanders
# Out:
#    contbr_st  contbr_nm  contb_receipt_amt
# 0         AL        521       1.580537e+05
# 1         AR        430       1.315956e+05
# 2         CA      28021       1.084799e+07
# 3         CO       3617       1.155217e+06
# 4         IA       1011       3.019115e+05
# 5         ID        502       1.486526e+05
# 6         ME       1040       3.210165e+05
# 7         MI       3456       1.092488e+06
# 8         MN       2496       7.883580e+05
# 9         MO       1607       4.841365e+05
# 10        MS        203       5.769485e+04
# 11        NC       2625       8.484836e+05
# 12        ND        153       4.347063e+04
# 13        NH       1116       3.607131e+05
# 14        NV       1159       3.676424e+05
# 15        OK        731       2.282502e+05
# 16        SC        811       2.440443e+05
# 17        TN       1395       4.206987e+05
# 18        TX       5762       1.864429e+06
# 19        UT        913       2.700821e+05
# 20        VA       2787       9.685434e+05
# 21        VT       1824       6.330967e+05
# 22        WA       7648       2.764413e+06

# %%
# get dependent variable ready
y_sanders = delegates_st[["sanders_win","st_abb"]]
y_biden = delegates_st[["biden_win","st_abb"]]

# rename for merging dataframes
y_sanders.rename(columns={'st_abb': 'contbr_st'})
y_biden.rename(columns={'st_abb': 'contbr_st'})
# Out:
#     biden_win contbr_st
# 0           0        IA
# 1           0        NH
# 2           0        NV
# 3           1        SC
# 4           1        AL
# 5           1        AR
# 6           0        CA
# 7           0        CO
# 8           1        ME
# 9           1        MN
# 10          1        NC
# 11          1        OK
# 12          1        TN
# 13          1        TX
# 14          0        UT
# 15          0        VT
# 16          1        VA
# 17          1        ID
# 18          1        MI
# 19          1        MS
# 20          1        MO
# 21          0        ND
# 22          0        WA

# %%
# merge the x and y
biden = pd.merge(y_biden,x_biden,on="contbr_st")
sanders = pd.merge(y_sanders,x_sanders,on="contbr_st")

# %%
biden
# Out:
#     biden_win contbr_st  contbr_nm  contb_receipt_amt
# 0           0        IA        397          181933.93
# 1           0        NH        373          218623.72
# 2           0        NV        694          794405.86
# 3           1        SC        674          521078.64
# 4           1        AL        356          201308.37
# 5           1        AR        159           72624.75
# 6           0        CA       9219         7654039.55
# 7           0        CO       1068          701015.58
# 8           1        ME        199           70132.80
# 9           1        MN        488          204336.67
# 10          1        NC       1287          753100.46
# 11          1        OK        225           78634.84
# 12          1        TN        746          534043.55
# 13          1        TX       2751         2295828.19
# 14          0        UT        294          180574.66
# 15          0        VT        161          122177.81
# 16          1        VA       2189         1537964.52
# 17          1        ID        258          190933.50
# 18          1        MI       1048          475071.01
# 19          1        MS        107           50771.00
# 20          1        MO        532          385733.77
# 21          0        ND         18            5052.33
# 22          0        WA       1623         1180548.53

# %% [markdown]
# **Biden**

# %%
# split train and test data

# randomly assign true or false to each row so that we have 70% true.
random.seed(444)
pts = np.random.rand(len(biden)) < 0.7

biden_train = biden[pts]
biden_test = biden[~pts]

biden_train_x = biden_train.copy()
biden_train_x = biden_train_x.drop('biden_win', 1)
biden_train_x = biden_train_x.drop('contbr_st', 1)
biden_train_y = biden_train['biden_win']

# %%
# train logistic regression model
logreg = LogisticRegression()
logreg.fit(biden_train_x, biden_train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# use test data to predict
biden_test_x = biden_test.copy()
biden_test_x = biden_test_x.drop('biden_win', 1)
biden_test_x = biden_test_x.drop('contbr_st', 1)
biden_test_y = biden_test['biden_win']

biden_pred = logreg.predict(biden_test_x)

# %%
# get accuracy
print('Accuracy : {:.3f}'.format(logreg.score(biden_test_x, biden_test_y)))
# Out:
# Accuracy : 0.571

# %% [markdown]
# **Sanders**

# %%
# split train and test data

# randomly assign true or false to each row so that we have 70% true.
random.seed(44)
pts = np.random.rand(len(sanders)) < 0.7

sanders_train = sanders[pts]
sanders_test = sanders[~pts]

sanders_train_x = sanders_train.copy()
sanders_train_x = sanders_train_x.drop('sanders_win', 1)
sanders_train_x = sanders_train_x.drop('contbr_st', 1)
sanders_train_y = sanders_train['sanders_win']

# train logistic regression model
logreg = LogisticRegression()
logreg.fit(sanders_train_x, sanders_train_y)

# use test data to predict
sanders_test_x = sanders_test.copy()
sanders_test_x = sanders_test_x.drop('sanders_win', 1)
sanders_test_x = sanders_test_x.drop('contbr_st', 1)
sanders_test_y = sanders_test['sanders_win']

sanders_pred = logreg.predict(sanders_test_x)

# get accuracy
print('Accuracy : {:.3f}'.format(logreg.score(sanders_test_x, sanders_test_y)))
# Out:
# Accuracy : 0.778

# %% [markdown]
# **Calculate the x variables based on diff of Biden and sanders**

# %%
whole = pd.merge(biden,sanders,on="contbr_st")

# %%
whole["contrb_nm_diff"] = whole["contbr_nm_x"] - whole["contbr_nm_y"] 
whole["contrb_amt_diff"] = whole["contb_receipt_amt_x"] - whole["contb_receipt_amt_y"]

# %%
biden_diff = whole[["biden_win","contrb_nm_diff","contrb_amt_diff"]]

# %%
biden_diff
# Out:
#     biden_win  contrb_nm_diff  contrb_amt_diff
# 0           0            -614    -1.199775e+05
# 1           0            -743    -1.420894e+05
# 2           0            -465     4.267634e+05
# 3           1            -137     2.770344e+05
# 4           1            -165     4.325471e+04
# 5           1            -271    -5.897084e+04
# 6           0          -18802    -3.193953e+06
# 7           0           -2549    -4.542010e+05
# 8           1            -841    -2.508837e+05
# 9           1           -2008    -5.840214e+05
# 10          1           -1338    -9.538318e+04
# 11          1            -506    -1.496154e+05
# 12          1            -649     1.133448e+05
# 13          1           -3011     4.313992e+05
# 14          0            -619    -8.950743e+04
# 15          0           -1663    -5.109188e+05
# 16          1            -598     5.694211e+05
# 17          1            -244     4.228087e+04
# 18          1           -2408    -6.174165e+05
# 19          1             -96    -6.923850e+03
# 20          1           -1075    -9.840271e+04
# 21          0            -135    -3.841830e+04
# 22          0           -6025    -1.583865e+06

# %%
# split train and test data

# randomly assign true or false to each row so that we have 70% true.
random.seed(4444)
pts = np.random.rand(len(biden_diff)) < 0.7

biden_diff_train = biden_diff[pts]
biden_diff_test = biden_diff[~pts]

biden_diff_train_x = biden_diff_train.copy()
biden_diff_train_x = biden_diff_train_x.drop('biden_win', 1)
biden_diff_train_y = biden_diff_train['biden_win']

# train logistic regression model
logreg = LogisticRegression()
logreg.fit(biden_diff_train_x, biden_diff_train_y)

# use test data to predict
biden_diff_test_x = biden_diff_test.copy()
biden_diff_test_x = biden_diff_test_x.drop('biden_win', 1)
biden_diff_test_y = biden_diff_test['biden_win']

biden_diff_pred = logreg.predict(biden_diff_test_x)

# get accuracy
print('Accuracy : {:.3f}'.format(logreg.score(biden_diff_test_x, biden_diff_test_y)))
# Out:
# Accuracy : 0.667

# %%
# CV
biden_diff_x = biden_diff.drop('biden_win', 1)
biden_diff_y = biden_diff['biden_win']

cv_predictions = cross_val_predict(logreg, biden_diff_x, biden_diff_y, cv=9)
cv_r2 = r2_score(biden_diff_y,cv_predictions)
print(cv_r2)
# Out:
# -0.2777777777777779

# %% [markdown]
# ## Conjoint the main and metadata based on artical index

# %%
main_reduced = main[["main_content","article_index"]]

# %%
meta_reduced = metadata[["abstract","article_index","headline","keywords","pub_date"]]

# %%
# in case the valueerror: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat
main_reduced.iloc[:]['article_index'] = main_reduced['article_index'].astype(int)
meta_reduced.iloc[:]['article_index'] = meta_reduced['article_index'].astype(int)

articles = pd.merge(main_reduced, meta_reduced, on='article_index')

# %%
articles.head()
# Out:
#                                         main_content  article_index  \
# 0  Before the first votes are cast in the Democra...             10
# 1  Before the first votes are cast in the Democra...             10
# 2  Before the first votes are cast in the Democra...             10
# 3  Before the first votes are cast in the Democra...             10
# 4  There was no drama this time, and no delay: Wi...             10
#
#                                             abstract  \
# 0  The Vermont senator has made exaggerated claim...
# 1  Joe Biden is “very much alive,” but the race i...
# 2  The Vermont senator has made exaggerated claim...
# 3  Joe Biden is “very much alive,” but the race i...
# 4  The Vermont senator has made exaggerated claim...
#
#                                             headline  \
# 0  {'main': 'Fact-Checking Bernie Sanders Before ...
# 1  {'main': '5 Takeaways From the South Carolina ...
# 2  {'main': 'Fact-Checking Bernie Sanders Before ...
# 3  {'main': '5 Takeaways From the South Carolina ...
# 4  {'main': 'Fact-Checking Bernie Sanders Before ...
#
#                                             keywords                  pub_date
# 0  [{'name': 'persons', 'value': 'Sanders, Bernar...  2020-02-01T16:00:55+0000
# 1  [{'name': 'subject', 'value': 'Presidential El...  2020-03-01T10:00:10+0000
# 2  [{'name': 'persons', 'value': 'Sanders, Bernar...  2020-02-01T16:00:55+0000
# 3  [{'name': 'subject', 'value': 'Presidential El...  2020-03-01T10:00:10+0000
# 4  [{'name': 'persons', 'value': 'Sanders, Bernar...  2020-02-01T16:00:55+0000

# %% [markdown]
# ## Clean Data

# %%
# tokenize
articles["main_tokenized"] = articles["main_content"].apply(lambda x: word_tokenize(x))
articles["abstract_tokenized"] = articles["abstract"].apply(lambda x: word_tokenize(x))

# %%
# remove punctuations
articles["main_tokenized"] = articles["main_tokenized"].apply(lambda x: " ".join([word for word in x if word not in string.punctuation]))
articles["abstract_tokenized"] = articles["abstract_tokenized"].apply(lambda x: " ".join([word for word in x if word not in string.punctuation]))

# %%
# load stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

# remove stopwords
articles["main_tokenized"] = articles["main_tokenized"].apply(lambda x: ' '.join([item for item in x.split() if item not in stop_words]))
articles["abstract_tokenized"] = articles["abstract_tokenized"].apply(lambda x: ' '.join([item for item in x.split() if item not in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to /Users/rayna/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# replace negations with not
articles["main_tokenized"] = articles["main_tokenized"].apply(lambda x: ' '.join(["not" if item.endswith("n't") else item for item in x.split()]))
articles["abstract_tokenized"] = articles["abstract_tokenized"].apply(lambda x: ' '.join(["not" if item.endswith("n't") else item for item in x.split()]))

# %%
# Attach all 'not's to the subsequent word.
def neg_concat(lst):
    e=""
    for item in re.split('(not )',lst):
        if item !='not ':
            e=e+item 
        else: e=e+"not-"
    return e

articles["main_tokenized"] = articles["main_tokenized"].apply(neg_concat)
articles["abstract_tokenized"] = articles["abstract_tokenized"].apply(neg_concat)

# %%
# stem
ps = PorterStemmer() 

# stem words
articles["main_tokenized"] = articles["main_tokenized"].apply(lambda x: ' '.join([ps.stem(item) for item in x.split()]))
articles["abstract_tokenized"] = articles["abstract_tokenized"].apply(lambda x: ' '.join([ps.stem(item) for item in x.split()]))

# %%
# tokenize again
articles["main_tokenized"] = articles["main_tokenized"].apply(lambda x: word_tokenize(x))
articles["abstract_tokenized"] = articles["abstract_tokenized"].apply(lambda x: word_tokenize(x))

# %% [markdown]
# ## Wordcloud

# %%
abstract = str(articles["abstract_tokenized"])

cloud = WordCloud(background_color = "white", max_words = 200, stopwords = set(STOPWORDS))
cloud.generate(abstract)
cloud.to_file("wordCloud_tokenized.png")

# %%
abstract = str(articles["abstract"])

cloud = WordCloud(background_color = "white", max_words = 200, stopwords = set(STOPWORDS))
cloud.generate(abstract)
cloud.to_file("wordCloud.png")

# %% [markdown]
# ## Bad of word

# %%
# concat all words in all reviews
words_abstract = articles["abstract_tokenized"].str.cat(sep=' ')
words_main = articles["main_tokenized"].str.cat(sep=' ')
# words is a string

# %%
# frequency count
word_freq_abstract = nltk.FreqDist(words_abstract.split())
word_freq_main = nltk.FreqDist(words_main.split())

# %%
# most frequent 500 words
most_freq_abstract = dict(word_freq_abstract.most_common(500))
most_freq_main = dict(word_freq_main.most_common(500))

# %%
# bag-of-word vector
vectorizer_abstract = CountVectorizer(most_freq_abstract, max_features = 500)
BoW_vector_abstract = vectorizer_abstract.fit_transform(articles["abstract_tokenized"]).toarray()

vectorizer_main = CountVectorizer(most_freq_main, max_features = 500)
BoW_vector_main = vectorizer_main.fit_transform(articles["main_tokenized"]).toarray()

# %%
BoW_vector_main.size
# 500*len (number of reviews)
# Out:
# 832500

# %% [markdown]
# # LDA model

# %%
def train_lda(data,column):
    """
    This function trains the lda model
    We setup parameters like number of topics, the chunksize to use in Hoffman method
    We also do 2 passes of the data since this is a small dataset, so we want the distributions to stabilize
    """
    num_topics = 10
    chunksize = 300
    dictionary = corpora.Dictionary(data[column])
    corpus = [dictionary.doc2bow(doc) for doc in data[column]]
    t1 = time.time()
    # low alpha means each document is only represented by a small number of topics, and vice versa
    # low eta means each topic is only represented by a small number of words, and vice versa
    lda = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary,
                   alpha=1e-2, eta=0.5e-2, chunksize=chunksize, minimum_probability=0.0, passes=2)
    t2 = time.time()
    print("Time to train LDA model on ", len(articles), "articles: ", (t2-t1)/60, "min")
    return dictionary,corpus,lda

# %%
# LDA modeling on abstract
dictionary,corpus,lda = train_lda(articles,"abstract_tokenized")
# Out:
# Time to train LDA model on  1665 articles:  0.013164166609446208 min

# %%
# LDA modeling on main_content
dictionary_main,corpus_main,lda_main = train_lda(articles,"main_tokenized")
# Out:
# Time to train LDA model on  1665 articles:  0.07948104937871298 min

# %%
# for abstract
# show_topics method shows the the top num_words contributing to num_topics number of random topics
lda.show_topics(num_topics=10, num_words=20)
# Out:
# [(0,
#   '0.143*"’" + 0.049*"here" + 0.046*"need" + 0.042*"end" + 0.042*"know" + 0.037*"day" + 0.035*"trump" + 0.035*"attack" + 0.034*"like" + 0.029*"presid" + 0.024*"possibl" + 0.024*"speaker" + 0.021*"american" + 0.021*"So" + 0.019*"elizabeth" + 0.018*"system" + 0.018*"thi" + 0.016*"the" + 0.014*"morn" + 0.014*"tip"'),
#  (1,
#   '0.084*"democrat" + 0.072*"’" + 0.063*"biden" + 0.063*"win" + 0.056*"joe" + 0.052*"2020" + 0.048*"tuesday" + 0.047*"voter" + 0.047*"race" + 0.047*"may" + 0.036*"A" + 0.034*"view" + 0.034*"presidenti" + 0.027*"far" + 0.026*"much" + 0.022*"candid" + 0.021*"support" + 0.020*"finish" + 0.014*"how" + 0.014*"while"'),
#  (2,
#   '0.059*"bloomberg" + 0.057*"’" + 0.057*"democrat" + 0.046*"the" + 0.035*"and" + 0.034*"super" + 0.034*"michael" + 0.034*"parti" + 0.029*"challeng" + 0.028*"tuesday" + 0.027*"take" + 0.027*"candid" + 0.023*"major" + 0.021*"want" + 0.020*"social" + 0.019*"outbreak" + 0.018*"—" + 0.017*"moder" + 0.016*"plan" + 0.016*"ad"'),
#  (3,
#   '0.103*"mani" + 0.060*"’" + 0.056*"one" + 0.051*"warren" + 0.050*"senat" + 0.037*"million" + 0.037*"super" + 0.036*"love" + 0.035*"us" + 0.031*"peopl" + 0.028*"said" + 0.027*"oppon" + 0.025*"record" + 0.024*"day" + 0.024*"announc" + 0.023*"help" + 0.023*"rais" + 0.019*"buttigieg" + 0.018*"listen" + 0.017*"check"'),
#  (4,
#   '0.113*"sander" + 0.073*"berni" + 0.055*"new" + 0.049*"’" + 0.049*"mr." + 0.029*"rival" + 0.028*"say" + 0.024*"chang" + 0.022*"candid" + 0.021*"presidenti" + 0.020*"polit" + 0.020*"contest" + 0.020*"primari" + 0.018*"hampshir" + 0.018*"state" + 0.018*"campaign" + 0.017*"warren" + 0.016*"poll" + 0.016*"still" + 0.016*"after"'),
#  (5,
#   '0.061*"the" + 0.054*"former" + 0.041*"black" + 0.039*"new" + 0.035*"democrat" + 0.033*"state" + 0.031*"seem" + 0.029*"close" + 0.028*"mayor" + 0.022*"As" + 0.021*"voter" + 0.021*"’" + 0.021*"global" + 0.021*"win" + 0.020*"york" + 0.019*"back" + 0.017*"see" + 0.016*"R." + 0.016*"In" + 0.015*"unclear"'),
#  (6,
#   '0.071*"candid" + 0.068*"could" + 0.056*"nation" + 0.054*"democrat" + 0.052*"nomin" + 0.046*"reader" + 0.042*"the" + 0.036*"elect" + 0.035*"iowa" + 0.035*"state" + 0.034*"klobuchar" + 0.029*"appear" + 0.028*"broker" + 0.028*"convent" + 0.025*"’" + 0.023*"ami" + 0.020*"caucus" + 0.017*"around" + 0.017*"result" + 0.016*"report"'),
#  (7,
#   '0.160*"”" + 0.160*"“" + 0.043*"call" + 0.041*"’" + 0.038*"presid" + 0.031*"campaign" + 0.025*"respons" + 0.023*"." + 0.021*"fund" + 0.019*"trump" + 0.019*"hous" + 0.018*"It" + 0.014*"the" + 0.013*"work" + 0.013*"voter" + 0.013*"confer" + 0.012*"loyalti" + 0.012*"romney" + 0.012*"mitt" + 0.012*"listen"'),
#  (8,
#   '0.102*"need" + 0.079*"know" + 0.069*"’" + 0.069*"here" + 0.050*"administr" + 0.037*"first" + 0.036*"\'s" + 0.034*"A" + 0.033*"pete" + 0.032*"coronaviru" + 0.028*"get" + 0.026*"biden" + 0.020*"R." + 0.019*"presid" + 0.019*"berni" + 0.019*"polit" + 0.018*"buttigieg" + 0.017*"sander" + 0.017*"also" + 0.016*"primari"'),
#  (9,
#   '0.067*"south" + 0.065*"carolina" + 0.062*"presid" + 0.039*"’" + 0.037*"primari" + 0.036*"trump" + 0.034*"week" + 0.033*"democrat" + 0.031*"face" + 0.028*"the" + 0.024*"victori" + 0.024*"tri" + 0.023*"campaign" + 0.023*"ralli" + 0.021*"year" + 0.019*"state" + 0.015*"—" + 0.014*"said" + 0.013*"vote" + 0.013*"polit"')]

# %%
# for abstract
# select and article at random from train_df
random_article_index = np.random.randint(len(articles))
bow = dictionary.doc2bow(articles.iloc[random_article_index,7])

# get the topic contributions for the document chosen at random above
doc_distribution = np.array([tup[1] for tup in lda.get_document_topics(bow=bow)])

# print the top 5 contributing topics and their words
for i in doc_distribution.argsort()[-5:][::-1]:
    print(i, lda.show_topic(topicid=i, topn=10), "\n")
# Out:
# 1 [('democrat', 0.08362304), ('’', 0.07182661), ('biden', 0.06315168), ('win', 0.06313797), ('joe', 0.056095697), ('2020', 0.051645026), ('tuesday', 0.047896482), ('voter', 0.047116693), ('race', 0.04686646), ('may', 0.046717227)]
#
# 9 [('south', 0.06736529), ('carolina', 0.06535404), ('presid', 0.062474508), ('’', 0.039399035), ('primari', 0.036983643), ('trump', 0.035761513), ('week', 0.03350238), ('democrat', 0.03282517), ('face', 0.031010348), ('the', 0.02820315)]
#
# 8 [('need', 0.10178944), ('know', 0.07860957), ('’', 0.068862416), ('here', 0.06874848), ('administr', 0.04975968), ('first', 0.036713727), ("'s", 0.03587094), ('A', 0.033693418), ('pete', 0.032548673), ('coronaviru', 0.032338865)]
#
# 7 [('”', 0.16018157), ('“', 0.16014685), ('call', 0.04254393), ('’', 0.041449428), ('presid', 0.037621513), ('campaign', 0.031342376), ('respons', 0.025049286), ('.', 0.022664975), ('fund', 0.02092896), ('trump', 0.019389745)]
#
# 6 [('candid', 0.07070525), ('could', 0.068363994), ('nation', 0.056426033), ('democrat', 0.053549115), ('nomin', 0.0517529), ('reader', 0.0463541), ('the', 0.041909557), ('elect', 0.03606378), ('iowa', 0.035385687), ('state', 0.03455645)]
